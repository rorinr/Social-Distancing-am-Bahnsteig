# %%
from ipynb.fs.full.whole_df import get_uppers, get_downers, get_whole_df, get_average_person_number, get_all_distances
import os
import numpy as np
import itertools
import pandas as pd
import statistics
import math
import seaborn as sb
import matplotlib.pyplot as plt

# %%
einstieg = [8.94,8.61,8.65,8.10,8.28,8.12,8.43,8.50,8.04,8.24,8.42,8.75,9.47,8.55,8.42,8.62,8.57,8.5,7.59,7.80,8.39,8.82,8.94,8.30,8.31,8.59,8.33,8.25,8.77,8.43]

# %%
dates = []
for filename in os.listdir(r"C:\Users\robin\Documents\Bachelorarbeit\Wartetrauben Analyse und Auswertung\Whole Dfs"):
    if "geo" not in filename:
        dates.append(filename)
dates = [i[7:9] + "." + i[5:7] + ".2020" for i in dates]

# %%
import matplotlib as mlp
plt.rcParams["font.family"] = "Microsoft Yi Baiti"
mlp.rc('font',family="Microsoft Yi Baiti")

# %%
sb.set()
sb.lineplot(dates, einstieg, c="darkslategrey", sort=False)
plt.ylabel("Einstiegszeit [s]", fontsize = 18, fontname = "Microsoft Yi Baiti")
plt.yticks(fontsize = 15, fontname = "Microsoft Yi Baiti")
plt.xlabel("Datum", fontsize = 18, fontname = "Microsoft Yi Baiti")
plt.title("Durchschnittliche Einstiegszeit einer Wartetraube", fontsize = 20,fontname="Microsoft Yi Baiti")

plt.xticks(dates, fontsize = 15, fontname = "Microsoft Yi Baiti", rotation = 45)
plt.locator_params(axis="x", nbins=8)
plt.tight_layout()

plt.savefig(r"Einstiegszeit\Einstiegszeit Wartetraube", dpi = 200)
# Out:
# C:\Users\robin\anaconda3\lib\site-packages\seaborn\relational.py:818: MatplotlibDeprecationWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'.  Passing multiple aliases for the same property will raise a TypeError in 3.3.
#   line, = ax.plot([], [], **kws)
# C:\Users\robin\anaconda3\lib\site-packages\seaborn\relational.py:829: MatplotlibDeprecationWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'.  Passing multiple aliases for the same property will raise a TypeError in 3.3.
#   line, = ax.plot(x, y, **kws)
