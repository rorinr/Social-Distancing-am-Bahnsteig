# %%
from ipynb.fs.full.whole_df import get_uppers, get_downers, get_whole_df, get_average_person_number, get_all_distances
import os
import numpy as np
import itertools
import pandas as pd
import statistics
import math
import seaborn as sb
import matplotlib.pyplot as plt

# %%
anzahl_df = pd.DataFrame(index = list(range(1,31)))

# %%
for filename in os.listdir(r"C:\Users\robin\Documents\Bachelorarbeit\Daten ZHDB"):
    if "geo" not in filename:
        column = []
        for i in range(1,31):
            df = get_whole_df(filename, i, 5)
            anzahl_wartetrauben = len(df["GroupID"].unique())
            column.append(anzahl_wartetrauben)
        anzahl_df[filename] = column
# Out:
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0205_6_20.txt
# ZHDB_0212_6_20.txt
# ZHDB_0212_6_20.txt
# ZHDB_0212_6_20.txt
# ZHDB_0212_6_20.txt
# ZHDB_0212_6_20.txt
# ZHDB_0212_6_20.txt
# ZHDB_0212_6_20.txt
# ZHDB_0212_6_20.txt
# ZHDB_0212_6_20.txt
# ZHDB_0212_6_20.txt
# ZHDB_0212_6_20.txt
# ZHDB_0212_6_20.txt
# ZHDB_0212_6_20.txt
# ZHDB_0212_6_20.txt
# ZHDB_0212_6_20.txt
# ZHDB_0212_6_20.txt
# ZHDB_0212_6_20.txt
# ...

# %%
anzahl_df.to_excel("Wartetrauben Häufigkeit/Häufigkeit Wartetrauben.xlsx")

# %%
anzahl_df
# Out:
#     ZHDB_0205_6_20.txt  ZHDB_0212_6_20.txt  ZHDB_0219_6_20.txt  \
# 1                 1051                 963                 993
# 2                  289                 279                 301
# 3                  167                 167                 181
# 4                  129                 125                 112
# 5                   94                  90                  91
# 6                   58                  86                  84
# 7                   85                  59                  58
# 8                   52                  41                  34
# 9                   39                  35                  47
# 10                  34                  33                  34
# 11                  31                  18                  26
# 12                  17                  18                  23
# 13                  16                  17                  22
# 14                  18                  12                  13
# ...
